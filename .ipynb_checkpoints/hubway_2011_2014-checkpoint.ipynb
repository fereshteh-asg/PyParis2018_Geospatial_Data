# %%
import pandas
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
s13=pandas.read_csv('Data/hubway_Trips_2013.csv')
s2012=pandas.read_csv('Data/hubway_Trips_2012.csv')
s2011=pandas.read_csv('Data/hubway_Trips_2011.csv')


#s20141=pandas.read_csv('Data/hubway_Trips_2014_1.csv')
#print(len(s20141))
#list(s20141)
# Out:
# /Users/fereshteh/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(s2011)
# Out:
# ['Duration',
#  'Start date',
#  'End date',
#  'Start station number',
#  'Start station name',
#  'End station number',
#  'End station name',
#  'Bike number',
#  'Member type',
#  'Zip code',
#  'Gender']

# %%
s20142=pandas.read_csv('Data/hubway_Trips_2014_2.csv')
s20141=pandas.read_csv('Data/hubway_Trips_2014_1.csv')
print(len(s20142))
list(s20142)
# Out:
# /Users/fereshteh/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 767241
# ['Duration',
#  'Start date',
#  'End date',
#  'Start station number',
#  'Start station name',
#  'End station number',
#  'End station name',
#  'Bike number',
#  'Member type',
#  'Zip code',
#  'Gender']

# %%
s1=pd.concat([s2012,s2011])
s_total=pd.concat([s1,s13])

s14=pd.concat([s20141,s20142])
print(len(s14), len(s1_3))
list(s14)

s_total=pd.concat([s14,s1_3])
len(s_total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-208e689f4b71> in <module>()
#       2 s1_3=pd.concat([s1,s13])
#       3 14
# ----> 4 s14=pd.concat([s20141,s20142])
#       5 print(len(s14), len(s1_3))
#       6 list(s14)
#
# NameError: name 's20141' is not defined

# %%
import calendar
from datetime import date

s13['Start date'] = pd.to_datetime(s13['Start date'])

s13['SDate'] = s13['Start date'].dt.date
s13['STime'] = s13['Start date'].dt.time

b=s13.groupby(s13['SDate']).count()

# %%
plt.ylim(0,5700)
plt.xticks(rotation='vertical')
plt.plot(b['SDate'].index,b['SDate'], color='b',linewidth=1)
plt.show()

# %%
import calendar
from datetime import date

#s1=pandas.read_csv('Data/TripData/201510-hubway-tripdata.csv')
#s1=s_total
s1=s13
print(len(s1))
list(s1)



#print(type(s1.at[0, 'Start date']))
s1['Start date'] = pd.to_datetime(s1['Start date'])
#grouped = s1['starttime'].groupby(pd.TimeGrouper(freq='10Min'))


print('done')

s1['SDate'] = s1['Start date'].dt.date
s1['STime'] = s1['Start date'].dt.time
##s1['hour'] = [ts.hour for ts in s1['Start date']]
##s1['min'] = [ts.minute for ts in s1['Start date']]
##s1['month']=[ts.month for ts in s1['Start date']]
#s1['tlabel']=s1["SDate"].astype(str)  + s1["hour"].astype(str) 
##s1['day_of_week'] = s1['starttime'].dt.dayofweek 
#s1['day']= calendar.day_name[s1['starttime'].dt.date.weekday()]


#delets a column
#df = df.drop('Dates', axis=1)
#print(s2['starttime'])

b=s1.groupby(s1['SDate']).count()
##print(b['S_Date'].index)

#b=s1['day_of_week'].value_counts()

#print(b)
#list(s2['starttime'])
#plt.plot(s2['starttime'].index,s2['starttime'], color='k',linewidth=1)
#plt.show()
#s2=s1.groupby(s1['SDate']).count()
#s2
plt.ylim(0,5700)
plt.xticks(rotation='vertical')
plt.plot(b['SDate'].index,b['SDate'], color='k',linewidth=1)
plt.show()
# Out:
# 906876
# done
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SDate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-cee291e11f15> in <module>()
#      44 plt.ylim(0,5700)
# ...

# %%
fig = plt.figure()
#ax = s1[['Stime','SDate']].values.plot(kind='bar', use_index=True)
#ax2 = ax.twinx()
#ax2.plot(df[['sales_gr','net_pft_gr']].values, linestyle='-', marker='o', linewidth=2.0)

# %%
import matplotlib as mpl
mpl.use("pgf")
pgf_with_rc_fonts = {
    "font.family": "serif",
    "font.serif": [],                   # use latex default serif font
    "font.sans-serif": ["DejaVu Sans"], # use a specific sans-serif font
}
mpl.rcParams.update(pgf_with_rc_fonts)


plt.rc('text', usetex=True)
plt.rc('font', family='serif')


import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import datetime as dt

#s['starttime'] = pd.to_datetime(s['starttime'])
#b=s.groupby(s['SDate']).count()
plt.figure(figsize=(16,8))

#plt.suptitle('test title', fontsize=20)
plt.plot(b['SDate'].index,b['SDate'],color='k',linewidth=1, label='All users')
plt.plot(b4['Duration'].index,b4['Duration'], color='#808080',linewidth=1 ,label='Unknown')
plt.plot(b2['Duration'].index,b2['Duration'], color='c',linewidth=1 ,label='Male users')
plt.plot(b['SDate'].index,b3['Duration'], color='b',linewidth=1, label='Female users')

#plt.stackplot(b['SDate'].index,b['SDate'],color='#D3D3D3',linewidth=1.5)#, label='All users')
plt.ylim(0,6000)
plt.grid(True)
plt.ylabel('Ride Frequency per Day',fontsize=16)
plt.xlabel('Time',fontsize=16)
plt.xticks(rotation='45')
plt.title('Hubway rides from 2011 to 2013',fontsize=20)
plt.legend()
plt.grid(which = 'minor')
plt.legend(loc=2, fontsize=14)
plt.savefig('Figures/2011-13-1.pdf', format='pdf')
plt.show()
# Out:
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
s2=s13.loc[s13['Gender'] == 'Male']
s3=s13.loc[s13['Gender'] == 'Female']
s4=s13.loc[s13['Member type'] == 'Casual']

print('male',len(s2)/len(s13))
print('female',len(s3)/len(s13))
print('casual',len(s4)/len(s13))
# Out:
# male 0.550515175172791
# female 0.17987023584260692
# casual 0.2696145889846021

# %%
year=pandas.read_csv('Data/hubway_Trips_2014_1.csv')
year1=pandas.read_csv('Data/hubway_Trips_2014_2.csv')
print(len(year))
print(len(year1))
print(len(year1)+len(year1))
list(year)
# Out:
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 417473
# 767241
# 1534482
# ['Duration',
#  'Start date',
#  'End date',
#  'Start station number',
#  'Start station name',
#  'End station number',
#  'End station name',
#  'Bike number',
#  'Member type',
#  'Zip code',
#  'Gender']

# %%
b2=s2.groupby(s2['SDate']).count()
b3=s3.groupby(s3['SDate']).count()
b4=s4.groupby(s4['SDate']).count()

# %%
grouper = pd.TimeGrouper(freq='30T')

s2=s1.groupby(s1['starttime']).count()

ts=s1['starttime']
#ts = ts.cumsum()


plt.figure(figsize=(12,8))
##plt.plot(s2['stoptime'].index,s2['stoptime'], color='b')
#s2.plot(s2['stoptime'].index,s2['stoptime'])
plt.xticks(rotation='vertical')
plt.ylim(1,5.1)
plt.show() 

#print(s2['stoptime']).value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1875             try:
# -> 1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'starttime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-256-f5f636193531> in <module>()
# ...

# %%
b1=s1.groupby(s1['STime']).count()

b1['hour'] = [ts.hour for ts in b1.index]


b2=b1.groupby(['SDate','hour']).size()
#df.groupby(['col5', 'col2']).size()
#print(b1['stoptime'])
plt.plot(b1['stoptime'].index,b1['stoptime'], color='b' )#,linewidth=2)
labels=['mon','tues','weds','thurs','fri','sat','sun']
plt.xticks(b1['stoptime'].index, labels, rotation='vertical')

plt.show()
b1
# Out:
#           tripduration  starttime  stoptime  start station id  \
# STime
# 00:00:03             1          1         1                 1
# 00:00:14             2          2         2                 2
# 00:00:19             1          1         1                 1
# 00:00:20             1          1         1                 1
# 00:00:21             1          1         1                 1
# 00:00:23             1          1         1                 1
# 00:00:24             1          1         1                 1
# 00:00:25             1          1         1                 1
# 00:00:28             1          1         1                 1
# 00:00:45             1          1         1                 1
# 00:00:46             1          1         1                 1
# 00:00:48             1          1         1                 1
# 00:00:55             1          1         1                 1
# 00:00:57             1          1         1                 1
# ...

# %%
b1=s1.groupby(s1['STime']).count()

b1['hour'] = [ts.hour for ts in b1.index]
b1['min'] = [ts.minute for ts in b1.index]
b2=b1.groupby('hour').count()

plt.plot(b2['stoptime'].index,b2['stoptime'],color='b', label='Women Users',linewidth=2)

labels=['','','','3am','','','6am','','','9am','','','12pm','','','3pm','','','6mp','','','9pm']
plt.xticks(b2['stoptime'].index, labels, rotation='vertical')
#matplotlib.axes.Axes.set_xticklabels(labels=lebels, fontdict=None, minor=False)

plt.show()

# %%
#b1

# %%
print(a.size().order()[121:131].sum())
a.size().order()[121:131].index
# Out:
# 195747
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: order is deprecated, use sort_values(...)
#   from ipykernel import kernelapp as app
# Index(['M32011', 'M32009', 'M32037', 'D32022', 'D32005', 'M32018', 'B32016',
#        'D32016', 'A32010', 'M32006'],
#       dtype='object', name='Start station number')

# %%
b=s1.groupby(['End station number'])
print(b.size().order()[121:131].index)
b.size().order()[121:131].sum()
#print(len(b.size()))
# Out:
# Index(['B32010', 'M32005', 'M32009', 'B32016', 'D32005', 'D32022', 'D32016',
#        'M32018', 'A32010', 'M32006'],
#       dtype='object', name='End station number')
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: order is deprecated, use sort_values(...)
#   from ipykernel import kernelapp as app
# /Users/fereshteh/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: order is deprecated, use sort_values(...)
#   app.launch_new_instance()
# 198120

# %%
import sys

x=[2011,2012,2013,2014,2015,2016]
ytotal=[140974,530374,906876,1184714,1700000,1900000]
plt.ylim(0, 2000000)
plt.grid(True)
plt.ylabel("Frequency", color="g", fontsize=16)
plt.tick_params(axis="y", labelcolor="g")
plt.plot(x, ytotal, c = 'g',linewidth=2.5, label='Total number of Trips')
plt.legend(loc=4)

y2=[12, 17,18,22,25,36]
y3=[43,31,27,30,33.3,20.7]
y4=[43.7,51,55,60,61,63]
plt.twinx()
plt.ylabel("Percentage", color="k", fontsize=16)
plt.ylim(0,100)
plt.tick_params(axis="y", labelcolor="k")
plt.plot(x, y2, "b",marker='o', linewidth=2, label='Female users %')
plt.plot(x, y4, "b", marker='^',linewidth=2 ,label='Male users %')
plt.plot(x, y3, "b",marker='s', linewidth=1.5, label='Unsubscriber users %')

plt.xticks( rotation='vertical')
plt.legend(loc=2)
plt.savefig('Figures/Summary.pdf', format='pdf')
plt.show()
